# %% [markdown]
# # Trabajando con Datos en el Entorno de Ejecución
#
# 1. Necesitamos un archivo de configuración (podemos usar una copia del que hemos revisado)

# %%
version
# Out:
#                _
# platform       x86_64-w64-mingw32
# arch           x86_64
# os             mingw32
# crt            ucrt
# system         x86_64, mingw32
# status
# major          4
# minor          2.2
# year           2022
# month          10
# day            31
# svn rev        83211
# language       R
# version.string R version 4.2.2 (2022-10-31 ucrt)
# nickname       Innocent and Trusting

# %% [markdown]
# 2. Debemos identificar el directorio donde estamos trabajando para efectos de saber dónde vamos a guardar los archivos cuando los generemos:

# %%
getwd()
# Out:
# [1] "D:/Dropbox/UIS/00_CLASES/0003_Diplomado/Nueva carpeta"

# %% [markdown]
# ## Uno primeros pasos antes de empezar a trabajar.
#
# 1. Reconocemos el Entorno de ejecución (OK)
# 2. Veamos cómo asignar objetos:

# %%
x<-rnorm(5)
x
# Out:
# [1] -1.2348531  0.4198386 -0.5544474 -0.2119401 -0.9685799

# %%
age <- c(1,3,5,2,11,9,3,9,12,3)
weight <- c(4.4,5.3,7.2,5.2,8.5,7.3,6.0,10.4,10.2,6.1)

# %%
mean(weight)
# Out:
# [1] 7.06

# %%
sd(weight)
# Out:
# [1] 2.077498

# %%
cor(age,weight)
# Out:
# [1] 0.9075655

# %%
plot(age,weight)
# Out:
# plot without title

# %% [markdown]
# ## Cómo pedir ayuda?

# %%
help.start()
# Out:
# starting httpd help server ...
#  done
# If nothing happens, you should open
# 'http://127.0.0.1:31121/doc/html/index.html' yourself

# %%
help("foo")

# %%
?foo

# %%
help.search("foo")

# %%
??foo

# %%
example("foo")
# Out:
# Warning message in example("foo"):
# "no help found for 'foo'"

# %%
RSiteSearch("foo")
# Out:
# A search query has been submitted to https://search.r-project.org
# The results page should open in your browser shortly

# %%
apropos("foo", mode="function")
# Out:
# [1] "citFooter"

# %%
data()

# %%
vignette()

# %%
vignette("foo")
# Out:
# Warning message:
# "vignette 'foo' not found"

# %%
vignette('bit-demo')

# %% [markdown]
# ## Funciones para el espacio de trabajo

# %%
getwd()
# Out:
# [1] "D:/Dropbox/UIS/00_CLASES/0003_Diplomado/Nueva carpeta"

# %%
setwd("mydirectory")
# Out:
# Error in setwd("mydirectory"): no es posible cambiar el directorio de trabajo
# Traceback:
#
# 1. setwd("mydirectory")

# %%
setwd('Archivos')
# Out:
# Error in setwd("Archivos"): no es posible cambiar el directorio de trabajo
# Traceback:
#
# 1. setwd("Archivos")

# %%
getwd()
# Out:
# [1] "D:/Dropbox/UIS/00_CLASES/0003_Diplomado/Nueva carpeta"

# %%
ls() # Listar objetos
# Out:
# [1] "age"    "weight" "x"

# %%
rm() # Remover objetos

# %%
help(options)

# %%
options()
# Out:
# $add.smooth
# [1] TRUE
#
# $browserNLdisabled
# [1] FALSE
#
# $callr.condition_handler_cli_message
# function (msg)
# {
#     custom_handler <- getOption("cli.default_handler")
#     if (is.function(custom_handler)) {
#         custom_handler(msg)
#     }
#     else {
#         cli_server_default(msg)
#     }
# }
# <bytecode: 0x000002833ab5a450>
# <environment: namespace:cli>
#
# $CBoundsCheck
# [1] FALSE
#
# $check.bounds
# [1] FALSE
#
# $citation.bibtex.max
# [1] 1
#
# $continue
# [1] "+ "
#
# $contrasts
#         unordered           ordered
# "contr.treatment"      "contr.poly"
#
# $crayon.enabled
# [1] TRUE
#
# $defaultPackages
# [1] "datasets"  "utils"     "grDevices" "graphics"  "stats"     "methods"
#
# $demo.ask
# [1] "default"
#
# $deparse.cutoff
# [1] 60
#
# $device
# function (filename = null_filename, ...)
# ok_device(filename, ...)
# <bytecode: 0x000002833d4692f0>
# <environment: 0x000002833d468e58>
#
# $device.ask.default
# [1] FALSE
#
# $digits
# [1] 7
#
# $echo
# [1] FALSE
#
# $editor
# [1] "notepad"
#
# $encoding
# [1] "native.enc"
#
# $example.ask
# [1] "default"
#
# $expressions
# [1] 5000
#
# $help.search.types
# [1] "vignette" "demo"     "help"
#
# $help.try.all.packages
# [1] FALSE
#
# $help_type
# [1] "html"
#
# $HTTPUserAgent
# [1] "R (4.2.2 x86_64-w64-mingw32 x86_64 mingw32)"
#
# $install.packages.compile.from.source
# [1] "interactive"
#
# $internet.info
# [1] 2
#
# $jupyter.base_display_func
# Class method definition for method display_data()
# function (data, metadata = NULL)
# {
#     if (is.null(metadata)) {
#         metadata <- namedlist()
#     }
#     send_response("display_data", current_request, "iopub", list(data = data,
#         metadata = metadata))
#     invisible(TRUE)
# }
# <environment: 0x000002833df798e8>
#
# $jupyter.clear_output_func
# Class method definition for method clear_output()
# function (wait = TRUE)
# {
#     send_response("clear_output", current_request, "iopub", list(wait = wait))
# }
# <environment: 0x000002833df798e8>
#
# $jupyter.display_mimetypes
#  [1] "text/plain"                       "text/html"
#  [3] "text/markdown"                    "text/latex"
#  [5] "application/json"                 "application/javascript"
#  [7] "application/geo+json"             "application/vdom.v1+json"
#  [9] "application/vnd.plotly.v1+json"   "application/vnd.vegalite.v2+json"
# [11] "application/vnd.vega.v4+json"     "application/pdf"
# [13] "image/png"                        "image/jpeg"
# [15] "image/svg+xml"
#
# $jupyter.in_kernel
# [1] TRUE
#
# $jupyter.log_level
# [1] 1
#
# $jupyter.logfile
# [1] NA
#
# $jupyter.pager_classes
# [1] "packageIQR"            "help_files_with_topic"
#
# $jupyter.plot_mimetypes
# [1] "text/plain" "image/png"
#
# $jupyter.plot_scale
# [1] 2
#
# $jupyter.rich_display
# [1] TRUE
#
# $keep.parse.data
# [1] TRUE
#
# $keep.parse.data.pkgs
# [1] FALSE
#
# $keep.source
# [1] FALSE
#
# $keep.source.pkgs
# [1] FALSE
#
# $locatorBell
# [1] TRUE
#
# $mailer
# [1] "mailto"
#
# $matprod
# [1] "default"
#
# $max.print
# [1] 99999
#
# $menu.graphics
# [1] TRUE
#
# $na.action
# [1] "na.omit"
#
# $nwarnings
# [1] 50
#
# $OutDec
# [1] "."
#
# $pager
# function (files, header, title, delete.file)
# {
#     text <- title
#     for (path in files) {
#         text <- c(text, header, readLines(path))
#     }
#     if (delete.file)
#         file.remove(files)
#     data <- list(`text/plain` = paste(text, collapse = "\n"))
#     page(list(data = data, metadata = namedlist()))
# }
# <environment: 0x000002833dfec800>
#
# $papersize
# [1] "a4"
#
# $PCRE_limit_recursion
# [1] NA
#
# $PCRE_study
# [1] FALSE
#
# $PCRE_use_JIT
# [1] TRUE
#
# $pdfviewer
# [1] "C:/PROGRA~1/R/R-42~1.2/bin/x64/open.exe"
#
# $pkgType
# [1] "both"
#
# $prompt
# [1] "> "
#
# $repos
#                         CRAN
# "https://cran.r-project.org"
# attr(,"irkernel")
# [1] TRUE
#
# $repr.function.highlight
# [1] FALSE
#
# $repr.html.deduplicate
# [1] FALSE
#
# $repr.matrix.latex.colspec
# $repr.matrix.latex.colspec$row_head
# [1] "r|"
#
# $repr.matrix.latex.colspec$col
# [1] "l"
#
# $repr.matrix.latex.colspec$end
# [1] ""
#
#
# $repr.matrix.max.cols
# [1] 20
#
# $repr.matrix.max.rows
# [1] 60
#
# $repr.plot.antialias
# [1] "gray"
#
# $repr.plot.bg
# [1] "white"
#
# $repr.plot.family
# [1] "sans"
#
# $repr.plot.height
# [1] 7
#
# $repr.plot.pointsize
# [1] 12
#
# $repr.plot.quality
# [1] 90
#
# $repr.plot.res
# [1] 120
#
# $repr.plot.width
# [1] 7
#
# $repr.vector.max.items
# [1] 400
#
# $repr.vector.quote
# [1] TRUE
#
# $scipen
# [1] 0
#
# $show.coef.Pvalues
# [1] TRUE
#
# $show.error.messages
# [1] TRUE
#
# $show.signif.stars
# [1] TRUE
#
# $showErrorCalls
# [1] TRUE
#
# $str
# $str$strict.width
# [1] "no"
#
# $str$digits.d
# [1] 3
#
# $str$vec.len
# [1] 4
#
# $str$list.len
# [1] 99
#
# $str$deparse.lines
# NULL
#
# $str$drop.deparse.attr
# [1] TRUE
#
# $str$formatNum
# function (x, ...)
# format(x, trim = TRUE, drop0trailing = TRUE, ...)
# <environment: 0x0000028339362e70>
#
#
# $str.dendrogram.last
# [1] "`"
#
# $stringsAsFactors
# [1] FALSE
#
# $timeout
# [1] 60
#
# $try.outFile
# A connection with
# description "output"
# class       "textConnection"
# mode        "wr"
# text        "text"
# opened      "opened"
# can read    "no"
# can write   "yes"
#
# $ts.eps
# [1] 1e-05
#
# $ts.S.compat
# [1] FALSE
#
# $unzip
# [1] "internal"
#
# $useFancyQuotes
# [1] FALSE
#
# $verbose
# [1] FALSE
#
# $warn
# [1] 0
#
# $warning.length
# [1] 1000
#
# $width
# [1] 80
#
# $windowsTimeouts
# [1] 100 500

# %%
history()
# Out:
# Error in .External2(C_savehistory, file): 'savehistory' can only be used in Rgui and Rterm
# Traceback:
#
# 1. history()
# 2. savehistory(file1)

# %%
savehistory("myfile")
# Out:
# Error in .External2(C_savehistory, file): 'savehistory' can only be used in Rgui and Rterm
# Traceback:
#
# 1. savehistory("myfile")

# %%
loadhistory("myfile")
# Out:
# Error in .External2(C_loadhistory, file): 'loadhistory' can only be used in Rgui and Rterm
# Traceback:
#
# 1. loadhistory("myfile")

# %%
save.image("myfile")

# %%
save(objectlist, file="myfile")
# Out:
# Error in save(objectlist, file = "myfile"): object 'objectlist' not found
# Traceback:
#
# 1. save(objectlist, file = "myfile")
# 2. stop(sprintf(ngettext(n, "object %s not found", "objects %s not found"),
#  .     paste(sQuote(list[!ok]), collapse = ", ")), domain = NA)

# %%
load("myfile")
# Out:
# Warning message in readChar(con, 5L, useBytes = TRUE):
# "cannot open compressed file 'myfile', probable reason 'No such file or directory'"
# Error in readChar(con, 5L, useBytes = TRUE): no se puede abrir la conexión
# Traceback:
#
# 1. load("myfile")
# 2. readChar(con, 5L, useBytes = TRUE)

# %% [markdown]
# ### Veamos un ejemplo sencillo:

# %%
getwd()
# Out:
# [1] "D:/Dropbox/UIS/00_CLASES/0003_Diplomado/Nueva carpeta"

# %%
options()
# Out:
# $add.smooth
# [1] TRUE
#
# $browserNLdisabled
# [1] FALSE
#
# $callr.condition_handler_cli_message
# function (msg)
# {
#     custom_handler <- getOption("cli.default_handler")
#     if (is.function(custom_handler)) {
#         custom_handler(msg)
#     }
#     else {
#         cli_server_default(msg)
#     }
# }
# <bytecode: 0x000002833ab5a450>
# <environment: namespace:cli>
#
# $CBoundsCheck
# [1] FALSE
#
# $check.bounds
# [1] FALSE
#
# $citation.bibtex.max
# [1] 1
#
# $continue
# [1] "+ "
#
# $contrasts
#         unordered           ordered
# "contr.treatment"      "contr.poly"
#
# $crayon.enabled
# [1] TRUE
#
# $defaultPackages
# [1] "datasets"  "utils"     "grDevices" "graphics"  "stats"     "methods"
#
# $demo.ask
# [1] "default"
#
# $deparse.cutoff
# [1] 60
#
# $device
# function (filename = null_filename, ...)
# ok_device(filename, ...)
# <bytecode: 0x000002833d4692f0>
# <environment: 0x000002833d468e58>
#
# $device.ask.default
# [1] FALSE
#
# $digits
# [1] 7
#
# $echo
# [1] FALSE
#
# $editor
# [1] "notepad"
#
# $encoding
# [1] "native.enc"
#
# $example.ask
# [1] "default"
#
# $expressions
# [1] 5000
#
# $help.search.types
# [1] "vignette" "demo"     "help"
#
# $help.try.all.packages
# [1] FALSE
#
# $help_type
# [1] "html"
#
# $HTTPUserAgent
# [1] "R (4.2.2 x86_64-w64-mingw32 x86_64 mingw32)"
#
# $install.packages.compile.from.source
# [1] "interactive"
#
# $internet.info
# [1] 2
#
# $jupyter.base_display_func
# Class method definition for method display_data()
# function (data, metadata = NULL)
# {
#     if (is.null(metadata)) {
#         metadata <- namedlist()
#     }
#     send_response("display_data", current_request, "iopub", list(data = data,
#         metadata = metadata))
#     invisible(TRUE)
# }
# <environment: 0x000002833df798e8>
#
# $jupyter.clear_output_func
# Class method definition for method clear_output()
# function (wait = TRUE)
# {
#     send_response("clear_output", current_request, "iopub", list(wait = wait))
# }
# <environment: 0x000002833df798e8>
#
# $jupyter.display_mimetypes
#  [1] "text/plain"                       "text/html"
#  [3] "text/markdown"                    "text/latex"
#  [5] "application/json"                 "application/javascript"
#  [7] "application/geo+json"             "application/vdom.v1+json"
#  [9] "application/vnd.plotly.v1+json"   "application/vnd.vegalite.v2+json"
# [11] "application/vnd.vega.v4+json"     "application/pdf"
# [13] "image/png"                        "image/jpeg"
# [15] "image/svg+xml"
#
# $jupyter.in_kernel
# [1] TRUE
#
# $jupyter.log_level
# [1] 1
#
# $jupyter.logfile
# [1] NA
#
# $jupyter.pager_classes
# [1] "packageIQR"            "help_files_with_topic"
#
# $jupyter.plot_mimetypes
# [1] "text/plain" "image/png"
#
# $jupyter.plot_scale
# [1] 2
#
# $jupyter.rich_display
# [1] TRUE
#
# $keep.parse.data
# [1] TRUE
#
# $keep.parse.data.pkgs
# [1] FALSE
#
# $keep.source
# [1] FALSE
#
# $keep.source.pkgs
# [1] FALSE
#
# $locatorBell
# [1] TRUE
#
# $mailer
# [1] "mailto"
#
# $matprod
# [1] "default"
#
# $max.print
# [1] 99999
#
# $menu.graphics
# [1] TRUE
#
# $na.action
# [1] "na.omit"
#
# $nwarnings
# [1] 50
#
# $OutDec
# [1] "."
#
# $pager
# function (files, header, title, delete.file)
# {
#     text <- title
#     for (path in files) {
#         text <- c(text, header, readLines(path))
#     }
#     if (delete.file)
#         file.remove(files)
#     data <- list(`text/plain` = paste(text, collapse = "\n"))
#     page(list(data = data, metadata = namedlist()))
# }
# <environment: 0x000002833dfec800>
#
# $papersize
# [1] "a4"
#
# $PCRE_limit_recursion
# [1] NA
#
# $PCRE_study
# [1] FALSE
#
# $PCRE_use_JIT
# [1] TRUE
#
# $pdfviewer
# [1] "C:/PROGRA~1/R/R-42~1.2/bin/x64/open.exe"
#
# $pkgType
# [1] "both"
#
# $prompt
# [1] "> "
#
# $repos
#                         CRAN
# "https://cran.r-project.org"
# attr(,"irkernel")
# [1] TRUE
#
# $repr.function.highlight
# [1] FALSE
#
# $repr.html.deduplicate
# [1] FALSE
#
# $repr.matrix.latex.colspec
# $repr.matrix.latex.colspec$row_head
# [1] "r|"
#
# $repr.matrix.latex.colspec$col
# [1] "l"
#
# $repr.matrix.latex.colspec$end
# [1] ""
#
#
# $repr.matrix.max.cols
# [1] 20
#
# $repr.matrix.max.rows
# [1] 60
#
# $repr.plot.antialias
# [1] "gray"
#
# $repr.plot.bg
# [1] "white"
#
# $repr.plot.family
# [1] "sans"
#
# $repr.plot.height
# [1] 7
#
# $repr.plot.pointsize
# [1] 12
#
# $repr.plot.quality
# [1] 90
#
# $repr.plot.res
# [1] 120
#
# $repr.plot.width
# [1] 7
#
# $repr.vector.max.items
# [1] 400
#
# $repr.vector.quote
# [1] TRUE
#
# $scipen
# [1] 0
#
# $show.coef.Pvalues
# [1] TRUE
#
# $show.error.messages
# [1] TRUE
#
# $show.signif.stars
# [1] TRUE
#
# $showErrorCalls
# [1] TRUE
#
# $str
# $str$strict.width
# [1] "no"
#
# $str$digits.d
# [1] 3
#
# $str$vec.len
# [1] 4
#
# $str$list.len
# [1] 99
#
# $str$deparse.lines
# NULL
#
# $str$drop.deparse.attr
# [1] TRUE
#
# $str$formatNum
# function (x, ...)
# format(x, trim = TRUE, drop0trailing = TRUE, ...)
# <environment: 0x0000028339362e70>
#
#
# $str.dendrogram.last
# [1] "`"
#
# $stringsAsFactors
# [1] FALSE
#
# $timeout
# [1] 60
#
# $try.outFile
# A connection with
# description "output"
# class       "textConnection"
# mode        "wr"
# text        "text"
# opened      "opened"
# can read    "no"
# can write   "yes"
#
# $ts.eps
# [1] 1e-05
#
# $ts.S.compat
# [1] FALSE
#
# $unzip
# [1] "internal"
#
# $useFancyQuotes
# [1] FALSE
#
# $verbose
# [1] FALSE
#
# $warn
# [1] 0
#
# $warning.length
# [1] 1000
#
# $width
# [1] 80
#
# $windowsTimeouts
# [1] 100 500

# %%
options(digits=3)

# %%
x <- runif(20)
summary(x)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.011   0.078   0.305   0.396   0.687   0.956

# %%
hist(x)
# Out:
# Plot with title "Histogram of x"

# %% [markdown]
# ## Trabajando con Paquetes o librerías
#
# Tenemos muchas opciones, hay librerías generales y librerías muy especializadas. Primero, veamos dónde se almacenan las librerías:

# %%
.libPaths()
# Out:
# [1] "C:/Users/UIS/Documents/R/win-library/4.2"
# [2] "C:/Program Files/R/R-4.2.2/library"

# %%
library()

# %%
install.packages("gclus")
# Out:
# Installing package into 'C:/Users/UIS/Documents/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'gclus' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\UIS\AppData\Local\Temp\RtmpKqBi61\downloaded_packages

# %%
update.packages()
# Out:
# Warning message:
# "package 'boot' in library 'C:/Program Files/R/R-4.2.2/library' will not be updated"
# Warning message:
# "package 'foreign' in library 'C:/Program Files/R/R-4.2.2/library' will not be updated"
# Warning message:
# "package 'Matrix' in library 'C:/Program Files/R/R-4.2.2/library' will not be updated"
# Warning message:
# "package 'nlme' in library 'C:/Program Files/R/R-4.2.2/library' will not be updated"
# Warning message:
# "package 'survival' in library 'C:/Program Files/R/R-4.2.2/library' will not be updated"
# Update? (Yes/no/cancel) c
# BH :
#  Version 1.78.0-0 installed in C:/Users/UIS/Documents/R/win-library/4.2
#  Version 1.81.0-1 available at https://cran.r-project.org
# cancelled by user

# %%
print(installed.packages())
# Out:
#                       Package
# abind                 "abind"
# ade4                  "ade4"
# admisc                "admisc"
# animation             "animation"
# aod                   "aod"
# askpass               "askpass"
# assertthat            "assertthat"
# backports             "backports"
# base64enc             "base64enc"
# bayestestR            "bayestestR"
# BBmisc                "BBmisc"
# bbmle                 "bbmle"
# bdsmatrix             "bdsmatrix"
# BH                    "BH"
# bigD                  "bigD"
# BiocGenerics          "BiocGenerics"
# BiocManager           "BiocManager"
# BiocVersion           "BiocVersion"
# bit                   "bit"
# bit64                 "bit64"
# bitops                "bitops"
# blob                  "blob"
# Boom                  "Boom"
# BoomSpikeSlab         "BoomSpikeSlab"
# boot                  "boot"
# brew                  "brew"
# brio                  "brio"
# broom                 "broom"
# bslib                 "bslib"
# bsts                  "bsts"
# ca                    "ca"
# cachem                "cachem"
# callr                 "callr"
# car                   "car"
# carData               "carData"
# caret                 "caret"
# caTools               "caTools"
# CausalImpact          "CausalImpact"
# cellranger            "cellranger"
# checkmate             "checkmate"
# chron                 "chron"
# classInt              "classInt"
# cli                   "cli"
# clipr                 "clipr"
# clock                 "clock"
# coda                  "coda"
# coin                  "coin"
# collections           "collections"
# colorspace            "colorspace"
# colourpicker          "colourpicker"
# commonmark            "commonmark"
# corrplot              "corrplot"
# corrr                 "corrr"
# cowplot               "cowplot"
# cpp11                 "cpp11"
# crayon                "crayon"
# credentials           "credentials"
# crosstalk             "crosstalk"
# crsmeta               "crsmeta"
# crul                  "crul"
# curl                  "curl"
# cvar                  "cvar"
# cyclocomp             "cyclocomp"
# DandEFA               "DandEFA"
# data.table            "data.table"
# DataExplorer          "DataExplorer"
# datawizard            "datawizard"
# DBI                   "DBI"
# dbplyr                "dbplyr"
# deldir                "deldir"
# dendextend            "dendextend"
# desc                  "desc"
# descr                 "descr"
# DescTools             "DescTools"
# devtools              "devtools"
# dichromat             "dichromat"
# diffobj               "diffobj"
# digest                "digest"
# distr                 "distr"
# distrEx               "distrEx"
# DistributionUtils     "DistributionUtils"
# doParallel            "doParallel"
# dotCall64             "dotCall64"
# downlit               "downlit"
# dplyr                 "dplyr"
# dsm                   "dsm"
# DT                    "DT"
# dtplyr                "dtplyr"
# dynlm                 "dynlm"
# e1071                 "e1071"
# effectsize            "effectsize"
# ellipse               "ellipse"
# ellipsis              "ellipsis"
# emmeans               "emmeans"
# entropy               "entropy"
# estimability          "estimability"
# evaluate              "evaluate"
# Exact                 "Exact"
# exams                 "exams"
# expm                  "expm"
# extrafont             "extrafont"
# extrafontdb           "extrafontdb"
# FactoClass            "FactoClass"
# factoextra            "factoextra"
# FactoInvestigate      "FactoInvestigate"
# FactoMineR            "FactoMineR"
# Factoshiny            "Factoshiny"
# fansi                 "fansi"
# faraway               "faraway"
# farver                "farver"
# fastICA               "fastICA"
# fastmap               "fastmap"
# fBasics               "fBasics"
# fGarch                "fGarch"
# fields                "fields"
# flashClust            "flashClust"
# FNN                   "FNN"
# fontawesome           "fontawesome"
# forcats               "forcats"
# foreach               "foreach"
# forecast              "forecast"
# foreign               "foreign"
# Formula               "Formula"
# fracdiff              "fracdiff"
# fs                    "fs"
# funModeling           "funModeling"
# future                "future"
# future.apply          "future.apply"
# gargle                "gargle"
# gbutils               "gbutils"
# gclus                 "gclus"
# gdata                 "gdata"
# gdtools               "gdtools"
# GeneralizedHyperbolic "GeneralizedHyperbolic"
# generics              "generics"
# geojson               "geojson"
# geojsonio             "geojsonio"
# geojsonsf             "geojsonsf"
# geometries            "geometries"
# gert                  "gert"
# GGally                "GGally"
# ggdendro              "ggdendro"
# ggeffects             "ggeffects"
# ggforce               "ggforce"
# ggformula             "ggformula"
# ggfortify             "ggfortify"
# gghighlight           "gghighlight"
# ggm                   "ggm"
# ggmap                 "ggmap"
# ggnewscale            "ggnewscale"
# ggplot2               "ggplot2"
# ggpubr                "ggpubr"
# ggrepel               "ggrepel"
# ggridges              "ggridges"
# ggsci                 "ggsci"
# ggsignif              "ggsignif"
# ggspatial             "ggspatial"
# ggstance              "ggstance"
# ggthemes              "ggthemes"
# gh                    "gh"
# gitcreds              "gitcreds"
# gld                   "gld"
# globals               "globals"
# glue                  "glue"
# gmodels               "gmodels"
# goftest               "goftest"
# googledrive           "googledrive"
# googlesheets4         "googlesheets4"
# gower                 "gower"
# gplots                "gplots"
# graph                 "graph"
# gridExtra             "gridExtra"
# gss                   "gss"
# gstat                 "gstat"
# gt                    "gt"
# gtable                "gtable"
# gtools                "gtools"
# hardhat               "hardhat"
# haven                 "haven"
# highr                 "highr"
# hipread               "hipread"
# Hmisc                 "Hmisc"
# hms                   "hms"
# hrbrthemes            "hrbrthemes"
# htmlTable             "htmlTable"
# htmltools             "htmltools"
# htmlwidgets           "htmlwidgets"
# httpcode              "httpcode"
# httpuv                "httpuv"
# httr                  "httr"
# httr2                 "httr2"
# ids                   "ids"
# igraph                "igraph"
# InformationValue      "InformationValue"
# ini                   "ini"
# insight               "insight"
# installr              "installr"
# interp                "interp"
# intervals             "intervals"
# ipred                 "ipred"
# ipumsr                "ipumsr"
# IRdisplay             "IRdisplay"
# IRkernel              "IRkernel"
# ISLR                  "ISLR"
# isoband               "isoband"
# iterators             "iterators"
# jpeg                  "jpeg"
# jqr                   "jqr"
# jquerylib             "jquerylib"
# jsonify               "jsonify"
# jsonlite              "jsonlite"
# juicyjuice            "juicyjuice"
# kernlab               "kernlab"
# knitr                 "knitr"
# ks                    "ks"
# labeling              "labeling"
# labelled              "labelled"
# labstatR              "labstatR"
# languageserver        "languageserver"
# later                 "later"
# latticeExtra          "latticeExtra"
# lava                  "lava"
# lazyeval              "lazyeval"
# leafem                "leafem"
# leaflet               "leaflet"
# leaflet.providers     "leaflet.providers"
# leafpop               "leafpop"
# leafsync              "leafsync"
# leaps                 "leaps"
# LearnBayes            "LearnBayes"
# libcoin               "libcoin"
# lifecycle             "lifecycle"
# lintr                 "lintr"
# listenv               "listenv"
# litteR                "litteR"
# lme4                  "lme4"
# lmom                  "lmom"
# lmtest                "lmtest"
# loa                   "loa"
# locfit                "locfit"
# lpSolve               "lpSolve"
# lubridate             "lubridate"
# lwgeom                "lwgeom"
# magick                "magick"
# magrittr              "magrittr"
# mapproj               "mapproj"
# maps                  "maps"
# maptools              "maptools"
# mapview               "mapview"
# markdown              "markdown"
# Matrix                "Matrix"
# MatrixModels          "MatrixModels"
# matrixStats           "matrixStats"
# maxLik                "maxLik"
# mclust                "mclust"
# memoise               "memoise"
# mice                  "mice"
# mime                  "mime"
# miniUI                "miniUI"
# minqa                 "minqa"
# misc3d                "misc3d"
# miscTools             "miscTools"
# missMDA               "missMDA"
# mitools               "mitools"
# mmtable2              "mmtable2"
# mnormt                "mnormt"
# ModelMetrics          "ModelMetrics"
# modelr                "modelr"
# modeltools            "modeltools"
# moments               "moments"
# mosaic                "mosaic"
# mosaicCore            "mosaicCore"
# mosaicData            "mosaicData"
# mrds                  "mrds"
# MTS                   "MTS"
# multcomp              "multcomp"
# multcompView          "multcompView"
# multicool             "multicool"
# munsell               "munsell"
# mvtnorm               "mvtnorm"
# ncf                   "ncf"
# networkD3             "networkD3"
# nlme                  "nlme"
# nloptr                "nloptr"
# nortest               "nortest"
# numDeriv              "numDeriv"
# openssl               "openssl"
# OpenStreetMap         "OpenStreetMap"
# optimx                "optimx"
# ordinal               "ordinal"
# osmdata               "osmdata"
# outliers              "outliers"
# pander                "pander"
# parallelly            "parallelly"
# parameters            "parameters"
# paran                 "paran"
# pbdZMQ                "pbdZMQ"
# pbkrtest              "pbkrtest"
# performance           "performance"
# PerformanceAnalytics  "PerformanceAnalytics"
# pgirmess              "pgirmess"
# pillar                "pillar"
# pixmap                "pixmap"
# pkgbuild              "pkgbuild"
# pkgconfig             "pkgconfig"
# pkgdown               "pkgdown"
# pkgload               "pkgload"
# plot3D                "plot3D"
# plotly                "plotly"
# plotrix               "plotrix"
# plyr                  "plyr"
# png                   "png"
# polyclip              "polyclip"
# polycor               "polycor"
# polynom               "polynom"
# ppcor                 "ppcor"
# pps                   "pps"
# pracma                "pracma"
# practicalgg           "practicalgg"
# praise                "praise"
# prettymapr            "prettymapr"
# prettyunits           "prettyunits"
# pROC                  "pROC"
# processx              "processx"
# prodlim               "prodlim"
# profvis               "profvis"
# progress              "progress"
# progressr             "progressr"
# PROJ                  "PROJ"
# proj4                 "proj4"
# promises              "promises"
# protolite             "protolite"
# proxy                 "proxy"
# ps                    "ps"
# psych                 "psych"
# purrr                 "purrr"
# qap                   "qap"
# quadprog              "quadprog"
# quantmod              "quantmod"
# quantreg              "quantreg"
# R.cache               "R.cache"
# R.methodsS3           "R.methodsS3"
# R.oo                  "R.oo"
# R.utils               "R.utils"
# R6                    "R6"
# rafalib               "rafalib"
# ragg                  "ragg"
# rapidjsonr            "rapidjsonr"
# rappdirs              "rappdirs"
# raster                "raster"
# rbibutils             "rbibutils"
# rcmdcheck             "rcmdcheck"
# RcmdrMisc             "RcmdrMisc"
# RColorBrewer          "RColorBrewer"
# Rcpp                  "Rcpp"
# RcppArmadillo         "RcppArmadillo"
# RcppEigen             "RcppEigen"
# Rdpack                "Rdpack"
# readr                 "readr"
# readstata13           "readstata13"
# readxl                "readxl"
# recipes               "recipes"
# registry              "registry"
# rematch               "rematch"
# rematch2              "rematch2"
# remotes               "remotes"
# repr                  "repr"
# reprex                "reprex"
# reproj                "reproj"
# reshape               "reshape"
# reshape2              "reshape2"
# rex                   "rex"
# rgdal                 "rgdal"
# rgeos                 "rgeos"
# rgl                   "rgl"
# RgoogleMaps           "RgoogleMaps"
# rJava                 "rJava"
# rjson                 "rjson"
# rlang                 "rlang"
# rmarkdown             "rmarkdown"
# rnaturalearth         "rnaturalearth"
# rnaturalearthdata     "rnaturalearthdata"
# ROCR                  "ROCR"
# rootSolve             "rootSolve"
# rosm                  "rosm"
# roxygen2              "roxygen2"
# rprojroot             "rprojroot"
# Rsolnp                "Rsolnp"
# rstatix               "rstatix"
# rstudioapi            "rstudioapi"
# Rttf2pt1              "Rttf2pt1"
# rugarch               "rugarch"
# rversions             "rversions"
# rvest                 "rvest"
# rworldmap             "rworldmap"
# s2                    "s2"
# sampleSelection       "sampleSelection"
# sampling              "sampling"
# samplingbook          "samplingbook"
# SamplingUtil          "SamplingUtil"
# sandwich              "sandwich"
# sass                  "sass"
# satellite             "satellite"
# scales                "scales"
# scatterplot3d         "scatterplot3d"
# scico                 "scico"
# selectr               "selectr"
# seriation             "seriation"
# servr                 "servr"
# sessioninfo           "sessioninfo"
# settings              "settings"
# sf                    "sf"
# sfheaders             "sfheaders"
# sfsmisc               "sfsmisc"
# sftime                "sftime"
# shiny                 "shiny"
# shinydashboard        "shinydashboard"
# shinyjqui             "shinyjqui"
# shinyjs               "shinyjs"
# sjlabelled            "sjlabelled"
# sjmisc                "sjmisc"
# sjPlot                "sjPlot"
# sjstats               "sjstats"
# SkewHyperbolic        "SkewHyperbolic"
# sourcetools           "sourcetools"
# sp                    "sp"
# spacetime             "spacetime"
# spam                  "spam"
# SparseM               "SparseM"
# spatialreg            "spatialreg"
# spatstat              "spatstat"
# spatstat.core         "spatstat.core"
# spatstat.data         "spatstat.data"
# spatstat.explore      "spatstat.explore"
# spatstat.geom         "spatstat.geom"
# spatstat.linnet       "spatstat.linnet"
# spatstat.model        "spatstat.model"
# spatstat.random       "spatstat.random"
# spatstat.sparse       "spatstat.sparse"
# spatstat.utils        "spatstat.utils"
# spd                   "spd"
# spData                "spData"
# spdep                 "spdep"
# spgwr                 "spgwr"
# splancs               "splancs"
# SQUAREM               "SQUAREM"
# stabledist            "stabledist"
# stars                 "stars"
# startupmsg            "startupmsg"
# statmod               "statmod"
# stests                "stests"
# stringi               "stringi"
# stringr               "stringr"
# styler                "styler"
# survey                "survey"
# survival              "survival"
# svglite               "svglite"
# sys                   "sys"
# systemfit             "systemfit"
# systemfonts           "systemfonts"
# TeachingDemos         "TeachingDemos"
# tensor                "tensor"
# terra                 "terra"
# testthat              "testthat"
# textshaping           "textshaping"
# TH.data               "TH.data"
# tibble                "tibble"
# tidyr                 "tidyr"
# tidyselect            "tidyselect"
# tidyverse             "tidyverse"
# timechange            "timechange"
# timeDate              "timeDate"
# timeSeries            "timeSeries"
# tinytex               "tinytex"
# tmap                  "tmap"
# tmaptools             "tmaptools"
# triebeard             "triebeard"
# truncnorm             "truncnorm"
# TSA                   "TSA"
# tseries               "tseries"
# TSP                   "TSP"
# TTR                   "TTR"
# tweenr                "tweenr"
# tzdb                  "tzdb"
# ucminf                "ucminf"
# units                 "units"
# urca                  "urca"
# urlchecker            "urlchecker"
# urltools              "urltools"
# usethis               "usethis"
# utf8                  "utf8"
# uuid                  "uuid"
# V8                    "V8"
# vctrs                 "vctrs"
# VGAM                  "VGAM"
# viridis               "viridis"
# viridisLite           "viridisLite"
# vroom                 "vroom"
# waldo                 "waldo"
# webshot               "webshot"
# whisker               "whisker"
# widgetframe           "widgetframe"
# withr                 "withr"
# wk                    "wk"
# xfun                  "xfun"
# XML                   "XML"
# xml2                  "xml2"
# xmlparsedata          "xmlparsedata"
# xopen                 "xopen"
# xtable                "xtable"
# xts                   "xts"
# yaml                  "yaml"
# zeallot               "zeallot"
# zip                   "zip"
# zoo                   "zoo"
# base                  "base"
# boot                  "boot"
# class                 "class"
# cluster               "cluster"
# codetools             "codetools"
# compiler              "compiler"
# datasets              "datasets"
# foreign               "foreign"
# graphics              "graphics"
# grDevices             "grDevices"
# grid                  "grid"
# KernSmooth            "KernSmooth"
# lattice               "lattice"
# MASS                  "MASS"
# Matrix                "Matrix"
# methods               "methods"
# mgcv                  "mgcv"
# nlme                  "nlme"
# nnet                  "nnet"
# parallel              "parallel"
# rpart                 "rpart"
# spatial               "spatial"
# splines               "splines"
# stats                 "stats"
# stats4                "stats4"
# survival              "survival"
# tcltk                 "tcltk"
# tools                 "tools"
# translations          "translations"
# utils                 "utils"
#                       LibPath                                    Version
# abind                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.4-5"
# ade4                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.7-20"
# admisc                "C:/Users/UIS/Documents/R/win-library/4.2" "0.30"
# animation             "C:/Users/UIS/Documents/R/win-library/4.2" "2.7"
# aod                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.2"
# askpass               "C:/Users/UIS/Documents/R/win-library/4.2" "1.1"
# assertthat            "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.1"
# backports             "C:/Users/UIS/Documents/R/win-library/4.2" "1.4.1"
# base64enc             "C:/Users/UIS/Documents/R/win-library/4.2" "0.1-3"
# bayestestR            "C:/Users/UIS/Documents/R/win-library/4.2" "0.13.0"
# BBmisc                "C:/Users/UIS/Documents/R/win-library/4.2" "1.13"
# bbmle                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.25"
# bdsmatrix             "C:/Users/UIS/Documents/R/win-library/4.2" "1.3-6"
# BH                    "C:/Users/UIS/Documents/R/win-library/4.2" "1.78.0-0"
# bigD                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.0"
# BiocGenerics          "C:/Users/UIS/Documents/R/win-library/4.2" "0.42.0"
# BiocManager           "C:/Users/UIS/Documents/R/win-library/4.2" "1.30.19"
# BiocVersion           "C:/Users/UIS/Documents/R/win-library/4.2" "3.15.2"
# bit                   "C:/Users/UIS/Documents/R/win-library/4.2" "4.0.5"
# bit64                 "C:/Users/UIS/Documents/R/win-library/4.2" "4.0.5"
# bitops                "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-7"
# blob                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.3"
# Boom                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.9.11"
# BoomSpikeSlab         "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.5"
# boot                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.3-28.1"
# brew                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-8"
# brio                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.3"
# broom                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.2"
# bslib                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.2"
# bsts                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.9.9"
# ca                    "C:/Users/UIS/Documents/R/win-library/4.2" "0.71.1"
# cachem                "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.6"
# callr                 "C:/Users/UIS/Documents/R/win-library/4.2" "3.7.3"
# car                   "C:/Users/UIS/Documents/R/win-library/4.2" "3.1-1"
# carData               "C:/Users/UIS/Documents/R/win-library/4.2" "3.0-5"
# caret                 "C:/Users/UIS/Documents/R/win-library/4.2" "6.0-93"
# caTools               "C:/Users/UIS/Documents/R/win-library/4.2" "1.18.2"
# CausalImpact          "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.0"
# cellranger            "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.0"
# checkmate             "C:/Users/UIS/Documents/R/win-library/4.2" "2.1.0"
# chron                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.3-58"
# classInt              "C:/Users/UIS/Documents/R/win-library/4.2" "0.4-8"
# cli                   "C:/Users/UIS/Documents/R/win-library/4.2" "3.6.0"
# clipr                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.8.0"
# clock                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.6.1"
# coda                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.19-4"
# coin                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.4-2"
# collections           "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.7"
# colorspace            "C:/Users/UIS/Documents/R/win-library/4.2" "2.0-3"
# colourpicker          "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.0"
# commonmark            "C:/Users/UIS/Documents/R/win-library/4.2" "1.8.1"
# corrplot              "C:/Users/UIS/Documents/R/win-library/4.2" "0.92"
# corrr                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.4"
# cowplot               "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.1"
# cpp11                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.3"
# crayon                "C:/Users/UIS/Documents/R/win-library/4.2" "1.5.2"
# credentials           "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.2"
# crosstalk             "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.0"
# crsmeta               "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.0"
# crul                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.3"
# curl                  "C:/Users/UIS/Documents/R/win-library/4.2" "4.3.3"
# cvar                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.5"
# cyclocomp             "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.0"
# DandEFA               "C:/Users/UIS/Documents/R/win-library/4.2" "1.6"
# data.table            "C:/Users/UIS/Documents/R/win-library/4.2" "1.14.6"
# DataExplorer          "C:/Users/UIS/Documents/R/win-library/4.2" "0.8.2"
# datawizard            "C:/Users/UIS/Documents/R/win-library/4.2" "0.6.5"
# DBI                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.3"
# dbplyr                "C:/Users/UIS/Documents/R/win-library/4.2" "2.2.1"
# deldir                "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-6"
# dendextend            "C:/Users/UIS/Documents/R/win-library/4.2" "1.16.0"
# desc                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.4.2"
# descr                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.5"
# DescTools             "C:/Users/UIS/Documents/R/win-library/4.2" "0.99.47"
# devtools              "C:/Users/UIS/Documents/R/win-library/4.2" "2.4.5"
# dichromat             "C:/Users/UIS/Documents/R/win-library/4.2" "2.0-0.1"
# diffobj               "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.5"
# digest                "C:/Users/UIS/Documents/R/win-library/4.2" "0.6.31"
# distr                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.9.1"
# distrEx               "C:/Users/UIS/Documents/R/win-library/4.2" "2.9.0"
# DistributionUtils     "C:/Users/UIS/Documents/R/win-library/4.2" "0.6-0"
# doParallel            "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.17"
# dotCall64             "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-2"
# downlit               "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.2"
# dplyr                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.10"
# dsm                   "C:/Users/UIS/Documents/R/win-library/4.2" "2.3.3"
# DT                    "C:/Users/UIS/Documents/R/win-library/4.2" "0.26"
# dtplyr                "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.2"
# dynlm                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.3-6"
# e1071                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.7-12"
# effectsize            "C:/Users/UIS/Documents/R/win-library/4.2" "0.8.2"
# ellipse               "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.3"
# ellipsis              "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.2"
# emmeans               "C:/Users/UIS/Documents/R/win-library/4.2" "1.8.3"
# entropy               "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.1"
# estimability          "C:/Users/UIS/Documents/R/win-library/4.2" "1.4.1"
# evaluate              "C:/Users/UIS/Documents/R/win-library/4.2" "0.19"
# Exact                 "C:/Users/UIS/Documents/R/win-library/4.2" "3.2"
# exams                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.4-0"
# expm                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.999-7"
# extrafont             "C:/Users/UIS/Documents/R/win-library/4.2" "0.18"
# extrafontdb           "C:/Users/UIS/Documents/R/win-library/4.2" "1.0"
# FactoClass            "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.7"
# factoextra            "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.7"
# FactoInvestigate      "C:/Users/UIS/Documents/R/win-library/4.2" "1.8"
# FactoMineR            "C:/Users/UIS/Documents/R/win-library/4.2" "2.7"
# Factoshiny            "C:/Users/UIS/Documents/R/win-library/4.2" "2.4"
# fansi                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.3"
# faraway               "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.8"
# farver                "C:/Users/UIS/Documents/R/win-library/4.2" "2.1.1"
# fastICA               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2-3"
# fastmap               "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.0"
# fBasics               "C:/Users/UIS/Documents/R/win-library/4.2" "4021.93"
# fGarch                "C:/Users/UIS/Documents/R/win-library/4.2" "4022.89"
# fields                "C:/Users/UIS/Documents/R/win-library/4.2" "14.1"
# flashClust            "C:/Users/UIS/Documents/R/win-library/4.2" "1.01-2"
# FNN                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.3.1"
# fontawesome           "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.0"
# forcats               "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.2"
# foreach               "C:/Users/UIS/Documents/R/win-library/4.2" "1.5.2"
# forecast              "C:/Users/UIS/Documents/R/win-library/4.2" "8.20"
# foreign               "C:/Users/UIS/Documents/R/win-library/4.2" "0.8-84"
# Formula               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2-4"
# fracdiff              "C:/Users/UIS/Documents/R/win-library/4.2" "1.5-2"
# fs                    "C:/Users/UIS/Documents/R/win-library/4.2" "1.5.2"
# funModeling           "C:/Users/UIS/Documents/R/win-library/4.2" "1.9.4"
# future                "C:/Users/UIS/Documents/R/win-library/4.2" "1.30.0"
# future.apply          "C:/Users/UIS/Documents/R/win-library/4.2" "1.10.0"
# gargle                "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.1"
# gbutils               "C:/Users/UIS/Documents/R/win-library/4.2" "0.5"
# gclus                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.2"
# gdata                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.18.0.1"
# gdtools               "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.4"
# GeneralizedHyperbolic "C:/Users/UIS/Documents/R/win-library/4.2" "0.8-4"
# generics              "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.3"
# geojson               "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.4"
# geojsonio             "C:/Users/UIS/Documents/R/win-library/4.2" "0.10.0"
# geojsonsf             "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.3"
# geometries            "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.0"
# gert                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.9.2"
# GGally                "C:/Users/UIS/Documents/R/win-library/4.2" "2.1.2"
# ggdendro              "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.23"
# ggeffects             "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.4"
# ggforce               "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.1"
# ggformula             "C:/Users/UIS/Documents/R/win-library/4.2" "0.10.2"
# ggfortify             "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.15"
# gghighlight           "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.0"
# ggm                   "C:/Users/UIS/Documents/R/win-library/4.2" "2.5"
# ggmap                 "C:/Users/UIS/Documents/R/win-library/4.2" "3.0.1"
# ggnewscale            "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.8"
# ggplot2               "C:/Users/UIS/Documents/R/win-library/4.2" "3.4.0"
# ggpubr                "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.0"
# ggrepel               "C:/Users/UIS/Documents/R/win-library/4.2" "0.9.2"
# ggridges              "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.4"
# ggsci                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.9"
# ggsignif              "C:/Users/UIS/Documents/R/win-library/4.2" "0.6.4"
# ggspatial             "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.7"
# ggstance              "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.6"
# ggthemes              "C:/Users/UIS/Documents/R/win-library/4.2" "4.2.4"
# gh                    "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.1"
# gitcreds              "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.2"
# gld                   "C:/Users/UIS/Documents/R/win-library/4.2" "2.6.6"
# globals               "C:/Users/UIS/Documents/R/win-library/4.2" "0.16.2"
# glue                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.6.2"
# gmodels               "C:/Users/UIS/Documents/R/win-library/4.2" "2.18.1.1"
# goftest               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2-3"
# googledrive           "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.0"
# googlesheets4         "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.1"
# gower                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.1"
# gplots                "C:/Users/UIS/Documents/R/win-library/4.2" "3.1.3"
# graph                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.74.0"
# gridExtra             "C:/Users/UIS/Documents/R/win-library/4.2" "2.3"
# gss                   "C:/Users/UIS/Documents/R/win-library/4.2" "2.2-3"
# gstat                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.1-0"
# gt                    "C:/Users/UIS/Documents/R/win-library/4.2" "0.8.0"
# gtable                "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.1"
# gtools                "C:/Users/UIS/Documents/R/win-library/4.2" "3.9.4"
# hardhat               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.0"
# haven                 "C:/Users/UIS/Documents/R/win-library/4.2" "2.5.1"
# highr                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.10"
# hipread               "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.3"
# Hmisc                 "C:/Users/UIS/Documents/R/win-library/4.2" "4.7-2"
# hms                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.1.2"
# hrbrthemes            "C:/Users/UIS/Documents/R/win-library/4.2" "0.8.0"
# htmlTable             "C:/Users/UIS/Documents/R/win-library/4.2" "2.4.1"
# htmltools             "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.4"
# htmlwidgets           "C:/Users/UIS/Documents/R/win-library/4.2" "1.6.1"
# httpcode              "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.0"
# httpuv                "C:/Users/UIS/Documents/R/win-library/4.2" "1.6.7"
# httr                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.4.4"
# httr2                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.2"
# ids                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.1"
# igraph                "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.5"
# InformationValue      "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.3"
# ini                   "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.1"
# insight               "C:/Users/UIS/Documents/R/win-library/4.2" "0.18.8"
# installr              "C:/Users/UIS/Documents/R/win-library/4.2" "0.23.4"
# interp                "C:/Users/UIS/Documents/R/win-library/4.2" "1.1-3"
# intervals             "C:/Users/UIS/Documents/R/win-library/4.2" "0.15.2"
# ipred                 "C:/Users/UIS/Documents/R/win-library/4.2" "0.9-13"
# ipumsr                "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.2"
# IRdisplay             "C:/Users/UIS/Documents/R/win-library/4.2" "1.1"
# IRkernel              "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.1"
# ISLR                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.4"
# isoband               "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.7"
# iterators             "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.14"
# jpeg                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.1-10"
# jqr                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.3"
# jquerylib             "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.4"
# jsonify               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.2"
# jsonlite              "C:/Users/UIS/Documents/R/win-library/4.2" "1.8.4"
# juicyjuice            "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.0"
# kernlab               "C:/Users/UIS/Documents/R/win-library/4.2" "0.9-31"
# knitr                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.41"
# ks                    "C:/Users/UIS/Documents/R/win-library/4.2" "1.14.0"
# labeling              "C:/Users/UIS/Documents/R/win-library/4.2" "0.4.2"
# labelled              "C:/Users/UIS/Documents/R/win-library/4.2" "2.10.0"
# labstatR              "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.13"
# languageserver        "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.15"
# later                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.3.0"
# latticeExtra          "C:/Users/UIS/Documents/R/win-library/4.2" "0.6-30"
# lava                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.7.1"
# lazyeval              "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.2"
# leafem                "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.0"
# leaflet               "C:/Users/UIS/Documents/R/win-library/4.2" "2.1.1"
# leaflet.providers     "C:/Users/UIS/Documents/R/win-library/4.2" "1.9.0"
# leafpop               "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.0"
# leafsync              "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.0"
# leaps                 "C:/Users/UIS/Documents/R/win-library/4.2" "3.1"
# LearnBayes            "C:/Users/UIS/Documents/R/win-library/4.2" "2.15.1"
# libcoin               "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-9"
# lifecycle             "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.3"
# lintr                 "C:/Users/UIS/Documents/R/win-library/4.2" "3.0.2"
# listenv               "C:/Users/UIS/Documents/R/win-library/4.2" "0.9.0"
# litteR                "C:/Users/UIS/Documents/R/win-library/4.2" "1.0.0"
# lme4                  "C:/Users/UIS/Documents/R/win-library/4.2" "1.1-31"
# lmom                  "C:/Users/UIS/Documents/R/win-library/4.2" "2.9"
# lmtest                "C:/Users/UIS/Documents/R/win-library/4.2" "0.9-40"
# loa                   "C:/Users/UIS/Documents/R/win-library/4.2" "0.2.47.1"
# locfit                "C:/Users/UIS/Documents/R/win-library/4.2" "1.5-9.7"
# lpSolve               "C:/Users/UIS/Documents/R/win-library/4.2" "5.6.17"
# lubridate             "C:/Users/UIS/Documents/R/win-library/4.2" "1.9.0"
# lwgeom                "C:/Users/UIS/Documents/R/win-library/4.2" "0.2-10"
# magick                "C:/Users/UIS/Documents/R/win-library/4.2" "2.7.3"
# magrittr              "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.3"
# mapproj               "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.9"
# maps                  "C:/Users/UIS/Documents/R/win-library/4.2" "3.4.1"
# maptools              "C:/Users/UIS/Documents/R/win-library/4.2" "1.1-6"
# mapview               "C:/Users/UIS/Documents/R/win-library/4.2" "2.11.0"
# markdown              "C:/Users/UIS/Documents/R/win-library/4.2" "1.4"
# Matrix                "C:/Users/UIS/Documents/R/win-library/4.2" "1.5-3"
# MatrixModels          "C:/Users/UIS/Documents/R/win-library/4.2" "0.5-1"
# matrixStats           "C:/Users/UIS/Documents/R/win-library/4.2" "0.63.0"
# maxLik                "C:/Users/UIS/Documents/R/win-library/4.2" "1.5-2"
# mclust                "C:/Users/UIS/Documents/R/win-library/4.2" "6.0.0"
# memoise               "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.1"
# mice                  "C:/Users/UIS/Documents/R/win-library/4.2" "3.15.0"
# mime                  "C:/Users/UIS/Documents/R/win-library/4.2" "0.12"
# miniUI                "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.1.1"
# minqa                 "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.5"
# misc3d                "C:/Users/UIS/Documents/R/win-library/4.2" "0.9-1"
# miscTools             "C:/Users/UIS/Documents/R/win-library/4.2" "0.6-26"
# missMDA               "C:/Users/UIS/Documents/R/win-library/4.2" "1.18"
# mitools               "C:/Users/UIS/Documents/R/win-library/4.2" "2.4"
# mmtable2              "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.3"
# mnormt                "C:/Users/UIS/Documents/R/win-library/4.2" "2.1.1"
# ModelMetrics          "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.2.2"
# modelr                "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.10"
# modeltools            "C:/Users/UIS/Documents/R/win-library/4.2" "0.2-23"
# moments               "C:/Users/UIS/Documents/R/win-library/4.2" "0.14.1"
# mosaic                "C:/Users/UIS/Documents/R/win-library/4.2" "1.8.4.2"
# mosaicCore            "C:/Users/UIS/Documents/R/win-library/4.2" "0.9.2.1"
# mosaicData            "C:/Users/UIS/Documents/R/win-library/4.2" "0.20.3"
# mrds                  "C:/Users/UIS/Documents/R/win-library/4.2" "2.2.8"
# MTS                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.2.1"
# multcomp              "C:/Users/UIS/Documents/R/win-library/4.2" "1.4-20"
# multcompView          "C:/Users/UIS/Documents/R/win-library/4.2" "0.1-8"
# multicool             "C:/Users/UIS/Documents/R/win-library/4.2" "0.1-12"
# munsell               "C:/Users/UIS/Documents/R/win-library/4.2" "0.5.0"
# mvtnorm               "C:/Users/UIS/Documents/R/win-library/4.2" "1.1-3"
# ncf                   "C:/Users/UIS/Documents/R/win-library/4.2" "1.3-2"
# networkD3             "C:/Users/UIS/Documents/R/win-library/4.2" "0.4"
# nlme                  "C:/Users/UIS/Documents/R/win-library/4.2" "3.1-161"
# nloptr                "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.3"
# nortest               "C:/Users/UIS/Documents/R/win-library/4.2" "1.0-4"
# numDeriv              "C:/Users/UIS/Documents/R/win-library/4.2" "2016.8-1.1"
# openssl               "C:/Users/UIS/Documents/R/win-library/4.2" "2.0.5"
# OpenStreetMap         "C:/Users/UIS/Documents/R/win-library/4.2" "0.3.4"
# optimx                "C:/Users/UIS/Documents/R/win-library/4.2" "2022-4.30"
# ordinal               "C:/Users/UIS/Documents/R/win-library/4.2" "2022.11-16"
# osmdata               "C:/Users/UIS/Documents/R/win-library/4.2" "0.1.10"
# outliers              "C:/Users/UIS/Documents/R/win-library/4.2" "0.15"
# ...
# bdsmatrix             "4.2.0"
# BH                    "4.2.0"
# bigD                  "4.2.2"
# BiocGenerics          "4.2.0"
# BiocManager           "4.2.2"
# BiocVersion           "4.2.0"
# bit                   "4.2.2"
# bit64                 "4.2.0"
# bitops                "4.2.0"
# blob                  "4.2.0"
# Boom                  "4.2.2"
# BoomSpikeSlab         "4.2.0"
# boot                  "4.2.2"
# brew                  "4.2.2"
# brio                  "4.2.0"
# broom                 "4.2.2"
# bslib                 "4.2.2"
# bsts                  "4.2.2"
# ca                    "4.2.2"
# cachem                "4.2.1"
# callr                 "4.2.2"
# car                   "4.2.2"
# carData               "4.2.0"
# caret                 "4.2.1"
# caTools               "4.2.1"
# CausalImpact          "4.2.2"
# cellranger            "4.2.0"
# checkmate             "4.2.0"
# chron                 "4.2.2"
# classInt              "4.2.2"
# cli                   "4.2.2"
# clipr                 "4.2.0"
# clock                 "4.2.2"
# coda                  "4.2.1"
# coin                  "4.2.2"
# collections           "4.2.2"
# colorspace            "4.2.0"
# colourpicker          "4.2.2"
# commonmark            "4.2.2"
# corrplot              "4.2.1"
# corrr                 "4.2.2"
# cowplot               "4.2.0"
# cpp11                 "4.2.1"
# crayon                "4.2.1"
# credentials           "4.2.1"
# crosstalk             "4.2.0"
# crsmeta               "4.2.0"
# crul                  "4.2.2"
# curl                  "4.2.2"
# cvar                  "4.2.2"
# cyclocomp             "4.2.0"
# DandEFA               "4.2.2"
# data.table            "4.2.2"
# DataExplorer          "4.2.2"
# datawizard            "4.2.2"
# DBI                   "4.2.0"
# dbplyr                "4.2.1"
# deldir                "4.2.0"
# dendextend            "4.2.1"
# desc                  "4.2.1"
# descr                 "4.2.1"
# DescTools             "4.2.2"
# devtools              "4.2.2"
# dichromat             "4.2.0"
# diffobj               "4.2.0"
# digest                "4.2.2"
# distr                 "4.2.2"
# distrEx               "4.2.2"
# DistributionUtils     "4.2.2"
# doParallel            "4.2.2"
# dotCall64             "4.2.2"
# downlit               "4.2.2"
# dplyr                 "4.2.2"
# dsm                   "4.2.1"
# DT                    "4.2.2"
# dtplyr                "4.2.2"
# dynlm                 "4.2.2"
# e1071                 "4.2.2"
# effectsize            "4.2.2"
# ellipse               "4.2.0"
# ellipsis              "4.2.0"
# emmeans               "4.2.2"
# entropy               "4.2.0"
# estimability          "4.2.1"
# evaluate              "4.2.2"
# Exact                 "4.2.1"
# exams                 "4.2.1"
# expm                  "4.2.2"
# extrafont             "4.2.0"
# extrafontdb           "4.2.0"
# FactoClass            "4.2.2"
# factoextra            "4.2.0"
# FactoInvestigate      "4.2.2"
# FactoMineR            "4.2.2"
# Factoshiny            "4.2.2"
# fansi                 "4.2.0"
# faraway               "4.2.2"
# farver                "4.2.1"
# fastICA               "4.2.2"
# fastmap               "4.2.0"
# fBasics               "4.2.2"
# fGarch                "4.2.2"
# fields                "4.2.2"
# flashClust            "4.2.0"
# FNN                   "4.2.0"
# fontawesome           "4.2.2"
# forcats               "4.2.2"
# foreach               "4.2.1"
# forecast              "4.2.2"
# foreign               "4.2.2"
# Formula               "4.2.0"
# fracdiff              "4.2.2"
# fs                    "4.2.0"
# funModeling           "4.2.2"
# future                "4.2.2"
# future.apply          "4.2.2"
# gargle                "4.2.2"
# gbutils               "4.2.2"
# gclus                 "4.2.2"
# gdata                 "4.2.1"
# gdtools               "4.2.1"
# GeneralizedHyperbolic "4.2.2"
# generics              "4.2.1"
# geojson               "4.2.1"
# geojsonio             "4.2.2"
# geojsonsf             "4.2.0"
# geometries            "4.2.0"
# gert                  "4.2.2"
# GGally                "4.2.1"
# ggdendro              "4.2.0"
# ggeffects             "4.2.2"
# ggforce               "4.2.2"
# ggformula             "4.2.1"
# ggfortify             "4.2.2"
# gghighlight           "4.2.2"
# ggm                   "4.2.1"
# ggmap                 "4.2.2"
# ggnewscale            "4.2.2"
# ggplot2               "4.2.2"
# ggpubr                "4.2.2"
# ggrepel               "4.2.2"
# ggridges              "4.2.1"
# ggsci                 "4.2.0"
# ggsignif              "4.2.2"
# ggspatial             "4.2.2"
# ggstance              "4.2.2"
# ggthemes              "4.2.2"
# gh                    "4.2.2"
# gitcreds              "4.2.2"
# gld                   "4.2.2"
# globals               "4.2.2"
# glue                  "4.2.0"
# gmodels               "4.2.1"
# goftest               "4.2.0"
# googledrive           "4.2.0"
# googlesheets4         "4.2.2"
# gower                 "4.2.2"
# gplots                "4.2.1"
# graph                 "4.2.0"
# gridExtra             "4.2.0"
# gss                   "4.2.0"
# gstat                 "4.2.2"
# gt                    "4.2.2"
# gtable                "4.2.1"
# gtools                "4.2.2"
# hardhat               "4.2.1"
# haven                 "4.2.2"
# highr                 "4.2.2"
# hipread               "4.2.1"
# Hmisc                 "4.2.2"
# hms                   "4.2.2"
# hrbrthemes            "4.2.1"
# htmlTable             "4.2.1"
# htmltools             "4.2.2"
# htmlwidgets           "4.2.2"
# httpcode              "4.2.0"
# httpuv                "4.2.2"
# httr                  "4.2.2"
# httr2                 "4.2.2"
# ids                   "4.2.0"
# igraph                "4.2.2"
# InformationValue      "4.2.1"
# ini                   "4.2.1"
# insight               "4.2.2"
# installr              "4.2.2"
# interp                "4.2.2"
# intervals             "4.2.0"
# ipred                 "4.2.1"
# ipumsr                "4.2.2"
# IRdisplay             "4.2.0"
# IRkernel              "4.2.1"
# ISLR                  "4.2.1"
# isoband               "4.2.2"
# iterators             "4.2.1"
# jpeg                  "4.2.2"
# jqr                   "4.2.0"
# jquerylib             "4.2.0"
# jsonify               "4.2.2"
# jsonlite              "4.2.2"
# juicyjuice            "4.2.2"
# kernlab               "4.2.0"
# knitr                 "4.2.2"
# ks                    "4.2.2"
# labeling              "4.2.0"
# labelled              "4.2.1"
# labstatR              "4.2.1"
# languageserver        "4.2.2"
# later                 "4.2.0"
# latticeExtra          "4.2.1"
# lava                  "4.2.2"
# lazyeval              "4.2.0"
# leafem                "4.2.0"
# leaflet               "4.2.0"
# leaflet.providers     "4.2.0"
# leafpop               "4.2.0"
# leafsync              "4.2.0"
# leaps                 "4.2.0"
# LearnBayes            "4.2.0"
# libcoin               "4.2.2"
# lifecycle             "4.2.1"
# lintr                 "4.2.2"
# listenv               "4.2.2"
# litteR                "4.2.2"
# lme4                  "4.2.2"
# lmom                  "4.2.0"
# lmtest                "4.2.1"
# loa                   "4.2.0"
# locfit                "4.2.2"
# lpSolve               "4.2.1"
# lubridate             "4.2.2"
# lwgeom                "4.2.2"
# magick                "4.2.0"
# magrittr              "4.2.0"
# mapproj               "4.2.2"
# maps                  "4.2.2"
# maptools              "4.2.2"
# mapview               "4.2.0"
# markdown              "4.2.2"
# Matrix                "4.2.2"
# MatrixModels          "4.2.2"
# matrixStats           "4.2.2"
# maxLik                "4.2.0"
# mclust                "4.2.2"
# memoise               "4.2.1"
# mice                  "4.2.2"
# mime                  "4.2.0"
# miniUI                "4.2.2"
# minqa                 "4.2.1"
# misc3d                "4.2.2"
# miscTools             "4.2.1"
# missMDA               "4.2.2"
# mitools               "4.2.0"
# mmtable2              "4.2.2"
# mnormt                "4.2.1"
# ModelMetrics          "4.2.1"
# modelr                "4.2.2"
# modeltools            "4.2.0"
# moments               "4.2.0"
# mosaic                "4.2.1"
# mosaicCore            "4.2.1"
# mosaicData            "4.2.1"
# mrds                  "4.2.2"
# MTS                   "4.2.2"
# multcomp              "4.2.2"
# multcompView          "4.2.2"
# multicool             "4.2.2"
# munsell               "4.2.0"
# mvtnorm               "4.2.0"
# ncf                   "4.2.0"
# networkD3             "4.2.2"
# nlme                  "4.2.2"
# nloptr                "4.2.0"
# nortest               "4.2.0"
# numDeriv              "4.2.0"
# openssl               "4.2.2"
# OpenStreetMap         "4.2.0"
# optimx                "4.2.1"
# ordinal               "4.2.2"
# osmdata               "4.2.0"
# outliers              "4.2.0"
# pander                "4.2.2"
# parallelly            "4.2.2"
# parameters            "4.2.2"
# paran                 "4.2.2"
# pbdZMQ                "4.2.1"
# pbkrtest              "4.2.0"
# performance           "4.2.2"
# PerformanceAnalytics  "4.2.2"
# pgirmess              "4.2.1"
# pillar                "4.2.1"
# pixmap                "4.2.0"
# pkgbuild              "4.2.2"
# pkgconfig             "4.2.0"
# pkgdown               "4.2.2"
# pkgload               "4.2.2"
# plot3D                "4.2.2"
# plotly                "4.2.2"
# plotrix               "4.2.0"
# plyr                  "4.2.2"
# png                   "4.2.2"
# polyclip              "4.2.1"
# polycor               "4.2.2"
# polynom               "4.2.0"
# ppcor                 "4.2.2"
# pps                   "4.2.0"
# pracma                "4.2.2"
# practicalgg           "4.2.0"
# praise                "4.2.0"
# prettymapr            "4.2.0"
# prettyunits           "4.2.0"
# pROC                  "4.2.1"
# processx              "4.2.2"
# prodlim               "4.2.1"
# profvis               "4.2.2"
# progress              "4.2.0"
# progressr             "4.2.2"
# PROJ                  "4.2.0"
# proj4                 "4.2.2"
# promises              "4.2.0"
# protolite             "4.2.2"
# proxy                 "4.2.0"
# ps                    "4.2.2"
# psych                 "4.2.2"
# purrr                 "4.2.2"
# qap                   "4.2.2"
# quadprog              "4.2.0"
# quantmod              "4.2.0"
# quantreg              "4.2.1"
# R.cache               "4.2.2"
# R.methodsS3           "4.2.0"
# R.oo                  "4.2.0"
# R.utils               "4.2.2"
# R6                    "4.2.0"
# rafalib               "4.2.0"
# ragg                  "4.2.2"
# rapidjsonr            "4.2.0"
# rappdirs              "4.2.0"
# raster                "4.2.2"
# rbibutils             "4.2.2"
# rcmdcheck             "4.2.1"
# RcmdrMisc             "4.2.1"
# RColorBrewer          "4.2.0"
# Rcpp                  "4.2.1"
# RcppArmadillo         "4.2.2"
# RcppEigen             "4.2.2"
# Rdpack                "4.2.2"
# readr                 "4.2.2"
# readstata13           "4.2.1"
# readxl                "4.2.2"
# recipes               "4.2.2"
# registry              "4.2.0"
# rematch               "4.2.0"
# rematch2              "4.2.0"
# remotes               "4.2.0"
# repr                  "4.2.0"
# reprex                "4.2.2"
# reproj                "4.2.2"
# reshape               "4.2.1"
# reshape2              "4.2.0"
# rex                   "4.2.0"
# rgdal                 "4.2.2"
# rgeos                 "4.2.2"
# rgl                   "4.2.2"
# RgoogleMaps           "4.2.0"
# rJava                 "4.2.0"
# rjson                 "4.2.0"
# rlang                 "4.2.1"
# rmarkdown             "4.2.2"
# rnaturalearth         "4.2.0"
# rnaturalearthdata     "4.2.0"
# ROCR                  "4.2.1"
# rootSolve             "4.2.0"
# rosm                  "4.2.0"
# roxygen2              "4.2.2"
# rprojroot             "4.2.0"
# Rsolnp                "4.2.1"
# rstatix               "4.2.2"
# rstudioapi            "4.2.2"
# Rttf2pt1              "4.2.1"
# rugarch               "4.2.2"
# rversions             "4.2.2"
# rvest                 "4.2.2"
# rworldmap             "4.2.1"
# s2                    "4.2.2"
# sampleSelection       "4.2.1"
# sampling              "4.2.0"
# samplingbook          "4.2.2"
# SamplingUtil          "4.2.1"
# sandwich              "4.2.1"
# sass                  "4.2.2"
# satellite             "4.2.0"
# scales                "4.2.1"
# scatterplot3d         "4.2.1"
# scico                 "4.2.2"
# selectr               "4.2.0"
# seriation             "4.2.2"
# servr                 "4.2.2"
# sessioninfo           "4.2.1"
# settings              "4.2.1"
# sf                    "4.2.2"
# sfheaders             "4.2.0"
# sfsmisc               "4.2.2"
# sftime                "4.2.2"
# shiny                 "4.2.2"
# shinydashboard        "4.2.2"
# shinyjqui             "4.2.2"
# shinyjs               "4.2.2"
# sjlabelled            "4.2.1"
# sjmisc                "4.2.1"
# sjPlot                "4.2.2"
# sjstats               "4.2.2"
# SkewHyperbolic        "4.2.2"
# sourcetools           "4.2.1"
# sp                    "4.2.2"
# spacetime             "4.2.0"
# spam                  "4.2.2"
# SparseM               "4.2.0"
# spatialreg            "4.2.2"
# spatstat              "4.2.2"
# spatstat.core         "4.2.1"
# spatstat.data         "4.2.2"
# spatstat.explore      "4.2.2"
# spatstat.geom         "4.2.2"
# spatstat.linnet       "4.2.2"
# spatstat.model        "4.2.2"
# spatstat.random       "4.2.1"
# spatstat.sparse       "4.2.2"
# spatstat.utils        "4.2.1"
# spd                   "4.2.2"
# spData                "4.2.2"
# spdep                 "4.2.2"
# spgwr                 "4.2.1"
# splancs               "4.2.1"
# SQUAREM               "4.2.0"
# stabledist            "4.2.1"
# stars                 "4.2.2"
# startupmsg            "4.2.0"
# statmod               "4.2.2"
# stests                "4.2.1"
# stringi               "4.2.1"
# stringr               "4.2.2"
# styler                "4.2.2"
# survey                "4.2.0"
# survival              "4.2.2"
# svglite               "4.2.2"
# sys                   "4.2.2"
# systemfit             "4.2.2"
# systemfonts           "4.2.0"
# TeachingDemos         "4.2.2"
# tensor                "4.2.0"
# terra                 "4.2.2"
# testthat              "4.2.2"
# textshaping           "4.2.2"
# TH.data               "4.2.2"
# tibble                "4.2.2"
# tidyr                 "4.2.1"
# tidyselect            "4.2.1"
# tidyverse             "4.2.2"
# timechange            "4.2.2"
# timeDate              "4.2.2"
# timeSeries            "4.2.2"
# tinytex               "4.2.2"
# tmap                  "4.2.0"
# tmaptools             "4.2.0"
# triebeard             "4.2.0"
# truncnorm             "4.2.0"
# TSA                   "4.2.2"
# tseries               "4.2.2"
# TSP                   "4.2.2"
# TTR                   "4.2.0"
# tweenr                "4.2.2"
# tzdb                  "4.2.0"
# ucminf                "4.2.1"
# units                 "4.2.2"
# urca                  "4.2.2"
# urlchecker            "4.2.2"
# urltools              "4.2.0"
# usethis               "4.2.1"
# utf8                  "4.2.0"
# uuid                  "4.2.0"
# V8                    "4.2.2"
# vctrs                 "4.2.2"
# VGAM                  "4.2.1"
# viridis               "4.2.0"
# viridisLite           "4.2.1"
# vroom                 "4.2.2"
# waldo                 "4.2.0"
# webshot               "4.2.2"
# whisker               "4.2.2"
# widgetframe           "4.2.0"
# withr                 "4.2.0"
# wk                    "4.2.2"
# xfun                  "4.2.2"
# XML                   "4.2.2"
# xml2                  "4.2.0"
# xmlparsedata          "4.2.0"
# xopen                 "4.2.1"
# xtable                "4.2.0"
# xts                   "4.2.2"
# yaml                  "4.2.1"
# zeallot               "4.2.1"
# zip                   "4.2.2"
# zoo                   "4.2.2"
# base                  "4.2.2"
# boot                  "4.2.2"
# class                 "4.2.2"
# cluster               "4.2.2"
# codetools             "4.2.2"
# compiler              "4.2.2"
# datasets              "4.2.2"
# foreign               "4.2.2"
# graphics              "4.2.2"
# grDevices             "4.2.2"
# grid                  "4.2.2"
# KernSmooth            "4.2.2"
# lattice               "4.2.2"
# MASS                  "4.2.2"
# Matrix                "4.2.2"
# methods               "4.2.2"
# mgcv                  "4.2.2"
# nlme                  "4.2.2"
# nnet                  "4.2.2"
# parallel              "4.2.2"
# rpart                 "4.2.2"
# spatial               "4.2.2"
# splines               "4.2.2"
# stats                 "4.2.2"
# stats4                "4.2.2"
# survival              "4.2.2"
# tcltk                 "4.2.2"
# tools                 "4.2.2"
# translations          "4.2.2"
# utils                 "4.2.2"

# %%
help(package="package_name")

# %% [markdown]
# ### Veamos un ejemplo

# %%
install.packages("vcd")
# Out:
# Installing package into 'C:/Users/UIS/Documents/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'vcd' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\UIS\AppData\Local\Temp\RtmpKqBi61\downloaded_packages

# %%
help(package="vcd")

# %%
library(vcd)
# Out:
# Loading required package: grid

# %%
help(Arthritis)

# %%
Arthritis
# Out:
#    ID Treatment Sex    Age Improved
# 1  57 Treated   Male   27  Some
# 2  46 Treated   Male   29  None
# 3  77 Treated   Male   30  None
# 4  17 Treated   Male   32  Marked
# 5  36 Treated   Male   46  Marked
# 6  23 Treated   Male   58  Marked
# 7  75 Treated   Male   59  None
# 8  39 Treated   Male   59  Marked
# 9  33 Treated   Male   63  None
# 10 55 Treated   Male   63  None
# 11 30 Treated   Male   64  None
# 12  5 Treated   Male   64  Some
# 13 63 Treated   Male   69  None
# 14 83 Treated   Male   70  Marked
# 15 66 Treated   Female 23  None
# 16 40 Treated   Female 32  None
# 17  6 Treated   Female 37  Some
# 18  7 Treated   Female 41  None
# 19 72 Treated   Female 41  Marked
# 20 37 Treated   Female 48  None
# 21 82 Treated   Female 48  Marked
# 22 53 Treated   Female 55  Marked
# 23 79 Treated   Female 55  Marked
# 24 26 Treated   Female 56  Marked
# 25 28 Treated   Female 57  Marked
# 26 60 Treated   Female 57  Marked
# 27 22 Treated   Female 57  Marked
# 28 27 Treated   Female 58  None
# 29  2 Treated   Female 59  Marked
# 30 59 Treated   Female 59  Marked
# ⋮  ⋮  ⋮         ⋮      ⋮   ⋮
# 55 29 Placebo   Female 30  None
# 56 50 Placebo   Female 31  Some
# 57 38 Placebo   Female 32  None
# 58 35 Placebo   Female 33  Marked
# 59 51 Placebo   Female 37  None
# 60 54 Placebo   Female 44  None
# 61 76 Placebo   Female 45  None
# 62 16 Placebo   Female 46  None
# 63 69 Placebo   Female 48  None
# 64 31 Placebo   Female 49  None
# 65 20 Placebo   Female 51  None
# 66 68 Placebo   Female 53  None
# 67 81 Placebo   Female 54  None
# 68  4 Placebo   Female 54  None
# 69 78 Placebo   Female 54  Marked
# 70 70 Placebo   Female 55  Marked
# 71 49 Placebo   Female 57  None
# 72 10 Placebo   Female 57  Some
# 73 47 Placebo   Female 58  Some
# 74 44 Placebo   Female 59  Some
# 75 24 Placebo   Female 59  Marked
# 76 48 Placebo   Female 61  None
# 77 19 Placebo   Female 63  Some
# 78  3 Placebo   Female 64  None
# 79 67 Placebo   Female 65  Marked
# 80 32 Placebo   Female 66  None
# 81 42 Placebo   Female 66  None
# 82 15 Placebo   Female 66  Some
# 83 71 Placebo   Female 68  Some
# 84  1 Placebo   Female 74  Marked

# %%
example(Arthritis)
# Out:
# Arthrt> data("Arthritis")
#
# Arthrt> art <- xtabs(~ Treatment + Improved, data = Arthritis, subset = Sex == "Female")
#
# Arthrt> art
#          Improved
# Treatment None Some Marked
#   Placebo   19    7      6
#   Treated    6    5     16
#
# Arthrt> mosaic(art, gp = shading_Friendly)
#
# Arthrt> mosaic(art, gp = shading_max)
# plot without title
# plot without title

# %% [markdown]
# ## Tipos de Objetos
#
# Hay muchos tipos de objetos, veamos los más comunes y cómo crearlos

# %%
## Vectores:
a <- c(1, 2, 5, 3, 6, -2, 4)
b <- c("one", "two", "three")
c <- c(TRUE, TRUE, TRUE, FALSE, TRUE, FALSE)

# %%
a
# Out:
# [1]  1  2  5  3  6 -2  4

# %%
b
# Out:
# [1] "one"   "two"   "three"

# %%
c
# Out:
# [1]  TRUE  TRUE  TRUE FALSE  TRUE FALSE

# %%
## Matrices:
y <- matrix(1:20, nrow=5, ncol=4)
y
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     6   11   16
# [2,] 2     7   12   17
# [3,] 3     8   13   18
# [4,] 4     9   14   19
# [5,] 5    10   15   20

# %%
print(y)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]    1    6   11   16
# [2,]    2    7   12   17
# [3,]    3    8   13   18
# [4,]    4    9   14   19
# [5,]    5   10   15   20

# %%
cells <- c(1,26,24,68)
rnames <- c("R1", "R2")
cnames <- c("C1", "C2")

# %%
mymatrix <- matrix(cells, nrow=2, ncol=2, byrow=TRUE,
dimnames=list(rnames, cnames))
print(mymatrix)
# Out:
#    C1 C2
# R1  1 26
# R2 24 68

# %%
mymatrix <- matrix(cells, nrow=2, ncol=2, byrow=FALSE,
dimnames=list(rnames, cnames))
print(mymatrix)
# Out:
#    C1 C2
# R1  1 24
# R2 26 68

# %%
## Arrays

dim1 <- c("A1", "A2")
dim2 <- c("B1", "B2", "B3")
dim3 <- c("C1", "C2", "C3", "C4")

# %%
z <- array(1:24, c(2, 3, 4), dimnames=list(dim1, dim2, dim3))
print(z)
# Out:
# , , C1
#
#    B1 B2 B3
# A1  1  3  5
# A2  2  4  6
#
# , , C2
#
#    B1 B2 B3
# A1  7  9 11
# A2  8 10 12
#
# , , C3
#
#    B1 B2 B3
# A1 13 15 17
# A2 14 16 18
#
# , , C4
#
#    B1 B2 B3
# A1 19 21 23
# A2 20 22 24

# %%
## Data frames
patientID <- c(1, 2, 3, 4)
age <- c(25, 34, 28, 52)
diabetes <- c("Type1", "Type2", "Type1", "Type1")
status <- c("Poor", "Improved", "Excellent", "Poor")
patientdata <- data.frame(patientID, age, diabetes, status)
patientdata
# Out:
#   patientID age diabetes status
# 1 1         25  Type1    Poor
# 2 2         34  Type2    Improved
# 3 3         28  Type1    Excellent
# 4 4         52  Type1    Poor

# %%
print(patientdata)
# Out:
#   patientID age diabetes    status
# 1         1  25    Type1      Poor
# 2         2  34    Type2  Improved
# 3         3  28    Type1 Excellent
# 4         4  52    Type1      Poor

# %% [markdown]
# ## Especificando Elementos

# %%
patientdata[1:2]
# Out:
#   patientID age
# 1 1         25
# 2 2         34
# 3 3         28
# 4 4         52

# %%
patientdata[c("diabetes", "status")]
# Out:
#   diabetes status
# 1 Type1    Poor
# 2 Type2    Improved
# 3 Type1    Excellent
# 4 Type1    Poor

# %%
patientdata$age
# Out:
# [1] 25 34 28 52

# %%
table(patientdata$diabetes, patientdata$status)
# Out:
#
#         Excellent Improved Poor
#   Type1         1        0    2
#   Type2         0        1    0

# %% [markdown]
# ## Attach, detach, whit
#
# Algunas funciones prácticas

# %%
data(mtcars)
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt   qsec vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.62 16.5 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.88 17.0 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.32 18.6 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.21 19.4 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.44 17.0 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.46 20.2 1  0  3    1

# %%
summary(mtcars$mpg)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    10.4    15.4    19.2    20.1    22.8    33.9

# %%
plot(mtcars$mpg, mtcars$disp)
# Out:
# plot without title

# %%
plot(mtcars$mpg, mtcars$wt)
# Out:
# plot without title

# %%
summary(mpg)
# Out:
# Error in summary(mpg): objeto 'mpg' no encontrado
# Traceback:
#
# 1. summary(mpg)

# %%
attach(mtcars)

# %%
summary(mpg)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    10.4    15.4    19.2    20.1    22.8    33.9

# %%
plot(mpg, disp)
# Out:
# plot without title

# %%
plot(mpg, wt)
# Out:
# plot without title

# %%
detach(mtcars)

# %%
summary(mpg)
# Out:
# Error in summary(mpg): objeto 'mpg' no encontrado
# Traceback:
#
# 1. summary(mpg)

# %%
with(mtcars, {
print(summary(mpg))
plot(mpg, disp)
plot(mpg, wt)
})
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    10.4    15.4    19.2    20.1    22.8    33.9
# plot without title
# plot without title

# %%
with(mtcars, {
stats <- summary(mpg)
stats
})
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    10.4    15.4    19.2    20.1    22.8    33.9

# %%
stats
# Out:
# Error in eval(expr, envir, enclos): objeto 'stats' no encontrado
# Traceback:

# %%
with(mtcars, {
nokeepstats <- summary(mpg)
keepstats <<- summary(mpg)
})

# %%
nokeepstats
# Out:
# Error in eval(expr, envir, enclos): objeto 'nokeepstats' no encontrado
# Traceback:

# %%
keepstats
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    10.4    15.4    19.2    20.1    22.8    33.9

# %% [markdown]
# ## Factores
#
# Se trata de otro tipo de objetos que describen variables cualitativas

# %%
diabetes <- c("Type1", "Type2", "Type1", "Type1")
status <- c("Poor", "Improved", "Excellent", "Poor")
status <- factor(status, ordered=TRUE)
status <- factor(status, order=TRUE,levels=c("Poor", "Improved", "Excellent"))
sex <- factor(c(1,2,2,1), levels=c(1, 2), labels=c("Male", "Female"))

# %%
diabetes
# Out:
# [1] "Type1" "Type2" "Type1" "Type1"

# %%
# Ejemplo:
patientID <- c(1, 2, 3, 4)
age <- c(25, 34, 28, 52)
diabetes <- c("Type1", "Type2", "Type1", "Type1")
status <- c("Poor", "Improved", "Excellent", "Poor")
diabetes <- factor(diabetes)
status <- factor(status, order=TRUE)
patientdata <- data.frame(patientID, age, diabetes, status)

# %%
str(patientdata)
# Out:
# 'data.frame':	4 obs. of  4 variables:
#  $ patientID: num  1 2 3 4
#  $ age      : num  25 34 28 52
#  $ diabetes : Factor w/ 2 levels "Type1","Type2": 1 2 1 1
#  $ status   : Ord.factor w/ 3 levels "Excellent"<"Improved"<..: 3 2 1 3

# %%
summary(patientdata)
# Out:
#    patientID         age        diabetes       status
#  Min.   :1.00   Min.   :25.0   Type1:3   Excellent:1
#  1st Qu.:1.75   1st Qu.:27.2   Type2:1   Improved :1
#  Median :2.50   Median :31.0             Poor     :2
#  Mean   :2.50   Mean   :34.8
#  3rd Qu.:3.25   3rd Qu.:38.5
#  Max.   :4.00   Max.   :52.0

# %%
## Listas
g <- "My First List"
h <- c(25, 26, 18, 39)
j <- matrix(1:10, nrow=5)
k <- c("one", "two", "three")
mylist <- list(title=g, ages=h, j, k)

# %%
print(mylist)
# Out:
# $title
# [1] "My First List"
#
# $ages
# [1] 25 26 18 39
#
# [[3]]
#      [,1] [,2]
# [1,]    1    6
# [2,]    2    7
# [3,]    3    8
# [4,]    4    9
# [5,]    5   10
#
# [[4]]
# [1] "one"   "two"   "three"

# %% [markdown]
# # Importación de datos
#
# ## LEER ARCHIVOS ASCII

# %%
## TIPO 1: solo datos
Datos <- read.table(file.choose(), skip = 0, header = FALSE, sep =',')
# Out:
# Error in file.choose(): selección de archivo cancelada
# Traceback:
#
# 1. read.table(file.choose(), skip = 0, header = FALSE, sep = ",")
# 2. file.choose()

# %%
Datos <- read.table('ejemplo-datos.txt', skip = 0, header = FALSE, sep =',')
head(Datos)

# %%
# TIPO 2: encabezado una linea + datos
Datos <- read.table('ejemplo-datos-header.txt', skip = 0, header = TRUE, sep =',')
head(Datos)

# %%
# TIPO 3: encabezado raro + datos
Datos <- read.table('ejemplo-datos-header-skip.txt', skip = 8, header = TRUE, sep =',')
head(Datos)

# %%
# LEER ARCHIVOS EXCEL
## install.packages("readxl") ## Si no está instalado
library("readxl")

# %%
Datos <- read_excel('datos.xlsx', sheet = 1)
head(Datos)

# %%
# Directamente de excel
install.packages('XLConnect')
library(XLConnect)
wb <- loadWorkbook("Libro1.xls", create = TRUE)
head(wb) # ?Funciona correctamente?

# %%
excel <- readWorksheet(wb, sheet = "Hoja1")
head(excel) # ?Funciona correctamente?

# %%
# en un solo paso
excel2 <- readWorksheet(loadWorkbook("Libro1.xls", create = TRUE), sheet = "Hoja1")
head(excel2) # ?Funciona correctamente?

# %%
## Importar archivos CSV
datos.csv <- read.csv("datos.csv", header = T)
head(datos.csv)

# %%
print(sapply(datos.csv, class))  # esto es para conocer la clase de cada variable

# %%
summary(datos.csv)

# %%
## Importar datos txt con tabulaci?n
datos.txt <- read.delim("datos.txt", header = TRUE, sep = "\t")
head(datos.txt)

# %%
datos.txt2 <- read.table("datos.txt", header = TRUE, sep = "\t")
head(datos.txt2)

# %%
# Desde una web:
Web <- "http://people.cst.cmich.edu/lee1c/spss/V16_materials/DataSets_v16/Diseaseoutbreak.txt"
datosWeb1 <- read.table(Web)  # o puede escribirse la direcci?n directamente dentro
head(datosWeb1)

# %%
# Otra alternativa:
Web <- "http://people.cst.cmich.edu/lee1c/spss/V16_materials/DataSets_v16/Diseaseoutbreak.txt"
nombres <- c("ID", "edad", "hijos", "coches", "yates", "motos")
datosWeb2 <- read.table(Web, col.names = nombres)
head(datosWeb2)  # un vistazo para ver c?mo resulta

# %%
## Desde SPSS:
library(foreign)
empleados1 <- read.spss("DatosSPSS.sav", to.data.frame = TRUE)
dim(empleados1)

# %%
head(empleados1)

# %%
# Otro ejemplo:
dspss <- read.spss("DatosSPSS.sav", to.data.frame = T)
dspss  # problema: variable dbay es una fecha y no sale como formato fecha :(

# %%
print(sapply(dspss, class))

# %%
# se puede arreglar:
dspss <- transform(dspss, bday = as.Date(ISOdate(1582, 10, 14) + dspss$bday))
dspss

# %%
## Desde Stata:
stata <- read.dta("datosStata.dta")
head(stata)

# %%
print(sapply(stata, class))
